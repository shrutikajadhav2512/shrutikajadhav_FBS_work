# %% [markdown]
# ### Given a 2D array, find its shape and size. Create a 5x4 array with random integers between 1 and 100, and print the shape and size.

# %%
import numpy as np

# %%
arr=np.random.randint(1,101,size=(5,4))
arr
# Out:
# array([[35, 67, 90, 18],
#        [44,  7, 29, 61],
#        [ 7, 86, 84, 49],
#        [87, 11, 10, 93],
#        [ 8, 25, 69, 93]], dtype=int32)

# %%
size=np.size(arr)
size
# Out:
# 20

# %%
shape=np.shape(arr)
shape
# Out:
# (5, 4)
