# %% [markdown]
# ### Generate an array of 10 random integers between 1 and 50.

# %%
import numpy as np

# %%
arr=np.random.randint(1,50,20)
arr
# Out:
# array([16, 22, 10, 16,  4, 47, 30, 38, 31, 23,  9, 28, 48, 40, 15,  6, 31,
#        10, 45, 39], dtype=int32)
