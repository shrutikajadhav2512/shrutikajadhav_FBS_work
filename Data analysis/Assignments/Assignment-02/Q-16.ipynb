# %% [markdown]
# ### Generate a 5x5 matrix of random floats between 0 and 1.

# %%
import numpy as np

# %%
arr1=np.random.rand(5,5)
arr1
# Out:
# array([[0.82954533, 0.84081064, 0.24098164, 0.48506208, 0.15506345],
#        [0.5798901 , 0.10159168, 0.06242958, 0.51590343, 0.79448817],
#        [0.61168716, 0.68449485, 0.9266322 , 0.02581956, 0.3536456 ],
#        [0.18526133, 0.7297559 , 0.37584912, 0.07634143, 0.55796595],
#        [0.23248483, 0.91527961, 0.13917435, 0.08872036, 0.82307658]])
