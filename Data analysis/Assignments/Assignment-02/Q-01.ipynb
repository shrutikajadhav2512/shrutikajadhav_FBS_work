# %% [markdown]
# ### Create a NumPy array containing integers from 0 to 9.

# %%
import numpy as np

# %%
arr=np.arange(0,9).reshape((3,3))
arr
# Out:
# array([[0, 1, 2],
#        [3, 4, 5],
#        [6, 7, 8]])
