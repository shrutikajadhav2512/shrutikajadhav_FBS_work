# %% [markdown]
# ## Numpy Introduction
# 1. Extensible Library
# 2. Faster than core python
# 3. Numeric python
# 4. Mathematical ooperations like arithmatic ,algebra,random sampling
# 5. Multi diamentional Array,matrix,srtings

# %% [markdown]
# ## Array
# 1. Array([])
# 2. Homogeous
# 3. Orderd
# 4. Mutable.size-Immutable
# 5. Duplicate elements are allowed
# 6. Numpy array is 50x faster than python list
