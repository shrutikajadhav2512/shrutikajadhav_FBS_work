# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Lineplot
# 1. Trends over time
# 2. Time series analysis
# 3. Upword/downword trend

# %%
import numpy as np

# %%
overs=np.arange(1,21)
team_1=np.random.randint(0,37,20)
team_2=np.random.randint(0,37,20)

# %%
team_1
# Out:
# array([14, 12, 31,  4, 12,  6, 15, 15, 29, 21, 22, 34, 22, 36, 18, 34, 26,
#        25, 23, 23], dtype=int32)

# %%
team1_score=np.cumsum(team_1)
team1_score
# Out:
# array([ 14,  26,  57,  61,  73,  79,  94, 109, 138, 159, 181, 215, 237,
#        273, 291, 325, 351, 376, 399, 422])

# %%
team2_score=np.cumsum(team_2)

# %%
plt.figure(figsize=(7,3))
plt.style.use("dark_background")
plt.plot(overs,team1_score,marker="o",color="red",label="team1")
plt.plot(overs,team2_score,marker=">",color="yellow",label="team2")
plt.xlabel("overs")
plt.ylabel("Score")
plt.title("Match summary")
plt.legend()
plt.show()

# %% [markdown]
# ## Scatterplot
# 1. Relationship between two variables
# 2. correlation
# 3. Positive correlation
# 4. Negative correlation

# %%
plt.figure(figsize=(7,3))
plt.scatter(overs,team_1,color="red",marker="o",label="team1")
plt.scatter(overs,team_2,color="yellow",marker=">",label="team2")
plt.legend()
plt.show()

# %% [markdown]
# ## Pie Chart
# 1. Showing Percentage distribution
# 2. Part to whole comparision
# 3. best to use when categories <=5

# %%
marks=[90,80,45,20,95,79]
subjects=["m1","m2","m3","m4","m5","m6"]

# %%
plt.pie(marks,labels=subjects,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ## Boxplot
# 1. Summary of distribution
# 2. Check outlier

# %%
plt.figure(figsize=(7,3))
age=[1,2,3,4,5,6,7,8,16]
plt.boxplot(age)
plt.show()
